# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')
print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
print("Data Information:\n")
df.info()
# Out:
# Data Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
print("Statstical Summary:\n")
df.describe()
# Out:
# Statstical Summary:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %%
print("Data Column names:\n")
for column in df.columns:
    print(column)
# Out:
# Data Column names:
#
# Survived
# Pclass
# Name
# Sex
# Age
# Siblings/Spouses Aboard
# Parents/Children Aboard
# Fare

# %%
print("How data looks like:\n")
df.head()
# Out:
# How data looks like:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
print("Shape of Data\n")
df.shape
# Out:
# Shape of Data
# (887, 8)

# %%
survivors = df[df['Survived'] == 1]
print("Total survivors:", len(survivors))
# Out:
# Total survivors: 342

# %%
print("NO. of Unique Values in each column:\n")
df.nunique()
# Out:
# NO. of Unique Values in each column:
# Survived                     2
# Pclass                       3
# Name                       887
# Sex                          2
# Age                         89
# Siblings/Spouses Aboard      7
# Parents/Children Aboard      7
# Fare                       248
# dtype: int64

# %%
print("Check for any null values:\n")
df.isnull().sum()
# Out:
# Check for any null values:
# Survived                   0
# Pclass                     0
# Name                       0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# dtype: int64

# %% [markdown]
# --> No Null values found in data

# %%
print("Total number of duplicates:\n")
df.duplicated().sum()
# Out:
# Total number of duplicates:
# np.int64(0)

# %%
print("Statical Functions:\n")
print("Mean: \n",df.mean(numeric_only=True))
print("Median: \n",df.median(numeric_only=True))
print("Mode: \n",df.mode(numeric_only=True))
print("Standard Deviation: \n",df.std(numeric_only=True))
print("Variance: \n",df.var(numeric_only=True))
print("Minimum: \n",df.min(numeric_only=True))
print("Maximum: \n",df.max(numeric_only=True))
# Out:
# Statical Functions:
#
# Mean:
#  Survived                    0.385569
# Pclass                      2.305524
# Age                        29.471443
# Siblings/Spouses Aboard     0.525366
# Parents/Children Aboard     0.383315
# Fare                       32.305420
# dtype: float64
# Median:
#  Survived                    0.0000
# Pclass                      3.0000
# Age                        28.0000
# Siblings/Spouses Aboard     0.0000
# Parents/Children Aboard     0.0000
# Fare                       14.4542
# dtype: float64
# Mode:
#     Survived  Pclass   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0         0       3  22.0                        0                        0
#
#    Fare
# 0  8.05
# Standard Deviation:
#  Survived                    0.487004
# Pclass                      0.836662
# Age                        14.121908
# Siblings/Spouses Aboard     1.104669
# Parents/Children Aboard     0.807466
# Fare                       49.782040
# dtype: float64
# ...

# %%
print("Countplot for Survived people:\n")
sns.countplot(data=df, x='Survived')
plt.title('Survival Count')
plt.legend(title='Survived')
plt.show()
# Out:
# Countplot for Survived people:
# C:\Users\mayba\AppData\Local\Temp\ipykernel_47516\2642965648.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Survived')

# %% [markdown]
# More No. of People have Died and only about 1/3 people have survived.

# %%
print("Age Distribution:\n")
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()
# Out:
# Age Distribution:

# %% [markdown]
# Most no. of Passengers are from 20 to 40 age.
# Also More no. of Adults Travelled in this Ship.

# %%
# Survival rate by gender
print("Survied vs gender:\n")
sns.barplot(x='Sex', y='Survived', data=df)
plt.title('Survival Rate by Gender')
plt.show()
# Out:
# Survied vs gender:

# %% [markdown]
# Females had a much higher survival rate than males.
# Most probably they follow "Women and Children" Safety first during Evacuation.

# %%
# Survival rate by Pclass
print("Survived vs Passenger Class:\n")
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Passenger Class')
plt.show()
# Out:
# Survived vs Passenger Class:

# %% [markdown]
# 1st class passengers had the highest survival rate.
# Higher class meant better access to lifeboats and priority during rescue.

# %%
# Countplot of Pclass and Survived
print("Countplot of Pclass and Survived:\n")
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Survival by Class')
plt.show()
# Out:
# Countplot of Pclass and Survived:

# %% [markdown]
# 1st class had more survivors than deaths, unlike 3rd class.
# In 3rd class, deaths were significantly higher than survivors.

# %%
# Fare distribution by class
print("Fare Distribution per Class:\n")
sns.violinplot(x='Pclass', y='Fare', data=df)
plt.title('Fare Distribution per Class')
plt.show()
# Out:
# Fare Distribution per Class:

# %% [markdown]
# Fare increases sharply with class.
# 1st class passengers paid the most, and some fares are extreme outliers.
# 3rd class fares were low and tightly packed.

# %%
# Boxplot of Age by Survival
print("Boxplot of Age by Survival:\n")
sns.boxplot(x='Survived', y='Age', data=df)
plt.title('Age Distribution by Survival')
plt.show()
# Out:
# Boxplot of Age by Survival:

# %% [markdown]
# Survivors were generally younger.

# %%
sns.pairplot(df, hue='Survived', height=2)

# %%
# Only numeric columns will be considered
correlation_matrix = df.corr(numeric_only=True)
print("Correlation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                           Survived    Pclass       Age  \
# Survived                 1.000000 -0.336528 -0.059665
# Pclass                  -0.336528  1.000000 -0.391492
# Age                     -0.059665 -0.391492  1.000000
# Siblings/Spouses Aboard -0.037082  0.085026 -0.297669
# Parents/Children Aboard  0.080097  0.020252 -0.193741
# Fare                     0.256179 -0.548919  0.112329
#
#                          Siblings/Spouses Aboard  Parents/Children Aboard  \
# Survived                               -0.037082                 0.080097
# Pclass                                  0.085026                 0.020252
# Age                                    -0.297669                -0.193741
# Siblings/Spouses Aboard                 1.000000                 0.414244
# Parents/Children Aboard                 0.414244                 1.000000
# Fare                                    0.158839                 0.215470
#
#                              Fare
# ...

# %%
print("Heatmap of Correlation Matrix:\n")
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, linewidths=0.5)
plt.title("Correlation Heatmap of Titanic Features")
plt.show()
# Out:
# Heatmap of Correlation Matrix:

# %%
numeric_cols = ['Age', 'Fare', 'Siblings/Spouses Aboard', 'Parents/Children Aboard']

plt.figure(figsize=(7, 5))
for i, col in enumerate(numeric_cols):
    plt.subplot(2, 2, i+1)
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")
    plt.tight_layout()
plt.suptitle("Boxplots to Find Outliers in Titanic Data", fontsize=16, y=1.02)
plt.show()

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] >= lower) & (df[column] <= upper)]


columns_to_clean = ['Age', 'Fare', 'Siblings/Spouses Aboard', 'Parents/Children Aboard']

for col in columns_to_clean:
    print(f"Removing outliers in: {col}")
    print("Before:", df.shape)
    data = remove_outliers_iqr(df, col)
    print("After:", data.shape)
    print("--------")
# Out:
# Removing outliers in: Age
# Before: (887, 8)
# After: (874, 8)
# --------
# Removing outliers in: Fare
# Before: (887, 8)
# After: (771, 8)
# --------
# Removing outliers in: Siblings/Spouses Aboard
# Before: (887, 8)
# After: (841, 8)
# --------
# Removing outliers in: Parents/Children Aboard
# Before: (887, 8)
# After: (674, 8)
# --------
